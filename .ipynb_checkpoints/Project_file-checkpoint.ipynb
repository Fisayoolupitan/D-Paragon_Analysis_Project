# %% [markdown]
# #### Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df_1 = pd.read_csv('Bank_Churn_Messy.xlsx - Account_Info.csv')
df_2 = pd.read_csv('Bank_Churn_Messy.xlsx - Customer_Info.csv')

# %%
df_1.head()
# Out:
#    CustomerId    Balance  NumOfProducts  HasCrCard  Tenure IsActiveMember  \
# 0    15634602       0.00              1          1       2            Yes
# 1    15647311   83807.86              1          1       1            Yes
# 2    15619304  159660.80              3          0       8             No
# 3    15701354       0.00              2          0       1             No
# 4    15737888  125510.82              1          1       2            Yes
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
merged_df = pd.merge(df_1, df_2, on='CustomerId', how='outer')

# %%
merged_df.head()
# Out:
#    CustomerId    Balance  NumOfProducts  HasCrCard  Tenure_x IsActiveMember  \
# 0    15565701  161993.89              1          0         9             No
# 1    15565706       0.00              1          1         1            Yes
# 2    15565714   64430.06              2          1         1            Yes
# 3    15565779   57809.32              1          0         6             No
# 4    15565796   96048.55              1          0        10             No
#
#    Exited   Surname  CreditScore Geography  Gender   Age  Tenure_y  \
# 0       0     Ferri          698     Spain  Female  39.0         9
# 1       1  Akobundu          612     Spain    Male  35.0         1
# 2       0  Cattaneo          601    France    Male  47.0         1
# 3       0      Kent          627   Germany  Female  30.0         6
# 4       0  Docherty          745   Germany    Male  48.0        10
#
#   EstimatedSalary
# 0       902,12.38
# 1       832,56.26
# 2       965,17.97
# 3       188258.49
# 4       745,10.65

# %%
merged_df=merged_df.drop("Tenure_y",axis=1)

# %%
merged_df=merged_df.rename(columns={"Tenure_x":"Tenure"})

# %%
merged_df
# Out:
#        CustomerId    Balance  NumOfProducts  HasCrCard  Tenure IsActiveMember  \
# 0        15565701  161993.89              1          0       9             No
# 1        15565706       0.00              1          1       1            Yes
# 2        15565714   64430.06              2          1       1            Yes
# 3        15565779   57809.32              1          0       6             No
# 4        15565796   96048.55              1          0      10             No
# ...           ...        ...            ...        ...     ...            ...
# 9996     15815628  113899.92              1          0       8             No
# 9997     15815645  152303.66              2          1       8            Yes
# 9998     15815656  100116.67              1          1       9            Yes
# 9999     15815660  154139.45              1          1       1            Yes
# 10000    15815690  113348.50              1          1       3            Yes
#
#        Exited   Surname  CreditScore Geography  Gender   Age EstimatedSalary
# 0           0     Ferri          698     Spain  Female  39.0       902,12.38
# 1           1  Akobundu          612     Spain    Male  35.0       832,56.26
# 2           0  Cattaneo          601    France    Male  47.0       965,17.97
# 3           0      Kent          627   Germany  Female  30.0       188258.49
# 4           0  Docherty          745   Germany    Male  48.0       745,10.65
# ...       ...       ...          ...       ...     ...   ...             ...
# 9996        0    Moysey          711    France  Female  37.0        802,15.2
# 9997        0    Akhtar          481    France    Male  37.0       175082.20
# 9998        1   Hopkins          541   Germany  Female  39.0       199808.10
# 9999        0     Mazzi          758    France  Female  34.0       607,28.89
# 10000       0  Akabueze          614     Spain  Female  40.0       777,89.01
#
# [10001 rows x 13 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10001 non-null  int64
#  1   Balance          10001 non-null  float64
#  2   NumOfProducts    10001 non-null  int64
#  3   HasCrCard        10001 non-null  int64
#  4   Tenure           10001 non-null  int64
#  5   IsActiveMember   10001 non-null  object
#  6   Exited           10001 non-null  int64
#  7   Surname          10001 non-null  object
#  8   CreditScore      10001 non-null  int64
#  9   Geography        10001 non-null  object
#  10  Gender           10001 non-null  object
#  11  Age              9998 non-null   float64
#  12  EstimatedSalary  10001 non-null  object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 1015.9+ KB

# %%
measures = [i for i in merged_df.select_dtypes(include=['int64','float64']). columns]
dimension = [i for i in merged_df.select_dtypes(include=['object']).columns]

# %%
measures
# Out:
# ['CustomerId',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'Tenure_x',
#  'Exited',
#  'CreditScore',
#  'Age',
#  'Tenure_y']

# %%
dimension
# Out:
# ['IsActiveMember', 'Surname', 'Geography', 'Gender', 'EstimatedSalary']

# %% [markdown]
# ### Analysis
#
# #### Question 1
#
# ###### How many customers do each country have?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by 'Geography' and count 'CustomerId'
geo_counts = merged_df.groupby('Geography')['CustomerId'].count()

colors=['blue','yellow','red']

# Plotting the bar chart
plt.figure(figsize=(8, 5))
bars = plt.bar(geo_counts.index, geo_counts.values, color=colors, edgecolor='black')

# Adding labels and title
plt.xlabel('Geography')
plt.ylabel('Number of Customers')
plt.title('Number of Customers per Geography')
plt.xticks(rotation=45)

# Add data labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, str(height),
             ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### What is the tally of Female and Male customers?

# %%
# Group by 'Gender' and count 'CustomerId'
gender_counts = merged_df.groupby('Gender')['CustomerId'].count()

colors = ['#FFFF27', '#6495ED']  # Yellow and cornflower blue

# Plotting the bar chart
plt.figure(figsize=(7, 5))
bars = plt.bar(gender_counts.index, gender_counts.values, color=colors, edgecolor='black')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.5, int(yval), 
             ha='center', va='bottom', fontsize=10)

# Adding labels and title
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.title('Number of Customers by Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Average Credit Score by country?

# %%
# Plotting
plt.figure(figsize=(8, 5))
bars = plt.bar(avg_credit_score.index, avg_credit_score.values, color='green', edgecolor='black')

# Add value labels on each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.5, round(yval, 1), ha='center', va='bottom')

# Labels and title
plt.title('Average Credit Score by Geography')
plt.xlabel('Geography')
plt.ylabel('Average Credit Score')
plt.tight_layout()
plt.show()

# %%
## categorize tenure

def categorize_tenure(value):
    if value <=2:
        return 'Short-termed'
    elif value > 2 and value <=6:
        return 'mid-termed'
    else:
        return 'long-termed'
          
merged_df['Tenure Category'] = merged_df['Tenure'].apply(categorize_tenure)

# %%
merged_df.head()
# Out:
#    CustomerId    Balance  NumOfProducts  HasCrCard  Tenure IsActiveMember  \
# 0    15565701  161993.89              1          0       9             No
# 1    15565706       0.00              1          1       1            Yes
# 2    15565714   64430.06              2          1       1            Yes
# 3    15565779   57809.32              1          0       6             No
# 4    15565796   96048.55              1          0      10             No
#
#    Exited   Surname  CreditScore Geography  Gender   Age EstimatedSalary  \
# 0       0     Ferri          698     Spain  Female  39.0       902,12.38
# 1       1  Akobundu          612     Spain    Male  35.0       832,56.26
# 2       0  Cattaneo          601    France    Male  47.0       965,17.97
# 3       0      Kent          627   Germany  Female  30.0       188258.49
# 4       0  Docherty          745   Germany    Male  48.0       745,10.65
#
#   Tenure Category
# 0     long-termed
# 1    Short-termed
# 2    Short-termed
# 3      mid-termed
# 4     long-termed

# %% [markdown]
# ###### Tenure for each customer has been Categorized in which 0-2 years is Short term, 3-6 years is Mid-term , >6years is considered long term

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10001 non-null  int64
#  1   Balance          10001 non-null  float64
#  2   NumOfProducts    10001 non-null  int64
#  3   HasCrCard        10001 non-null  int64
#  4   Tenure_x         10001 non-null  int64
#  5   IsActiveMember   10001 non-null  object
#  6   Exited           10001 non-null  int64
#  7   Surname          10001 non-null  object
#  8   CreditScore      10001 non-null  int64
#  9   Geography        10001 non-null  object
#  10  Gender           10001 non-null  object
#  11  Age              9998 non-null   float64
#  12  Tenure_y         10001 non-null  int64
#  13  EstimatedSalary  10001 non-null  object
# dtypes: float64(2), int64(7), object(5)
# memory usage: 1.1+ MB

# %% [markdown]
# ##### What is Average mode of the product Per Tenure Category?

# %%
# Group by 'Tenure Category' and get mode of 'NumOfProducts'
mode_num_products = merged_df.groupby('Tenure Category')['NumOfProducts'].agg(lambda x: x.mode().iloc[0])
# Plotting
plt.figure(figsize=(8, 5))
bars = plt.bar(mode_num_products.index, mode_num_products.values, color='mediumseagreen', edgecolor='black')
plt.title('Most Common Number of Products by Tenure Category')
plt.xlabel('Tenure Category')
plt.ylabel('Mode of NumOfProducts')
plt.tight_layout()
plt.show()

# %%
# Select relevant columns
top_5_salaries = merged_df[['CustomerId', 'Surname', 'EstimatedSalary' , 'Geography']]

# Sort by salary in descending order and take top 5
top_5_salaries = top_5_salaries.sort_values(by='EstimatedSalary', ascending=False).head(5)

# %%
top_5_salaries
# Out:
#       CustomerId    Surname  EstimatedSalary Geography
# 7640    15756954  Unknown_3       9999999.00    France
# 6533    15728693  Unknown_1       9999999.00   Germany
# 557     15580203  Unknown_2       9999999.00     Spain
# 3832    15662021   Lucciano        199992.48     Spain
# 2729    15634359       Dyer        199970.74   Germany

# %%
# Convert salary to numeric (if not already)
merged_df['EstimatedSalary'] = pd.to_numeric(merged_df['EstimatedSalary'], errors='coerce')

# Top 5 customers by salary
top5 = merged_df[['CustomerId', 'Surname', 'EstimatedSalary', 'Geography']].sort_values(
    by='EstimatedSalary', ascending=False).head(5)

# Combine surname and ID for better labeling
top5['Customer'] = top5['Surname'] + ' - ' + top5['CustomerId'].astype(str)

# Plot
plt.figure(figsize=(10, 6))
ax = sb.barplot(data=top5, x='EstimatedSalary', y='Customer', hue='Geography', dodge=False, palette='Set2')

# Add data labels at the end of each bar
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', padding=5)

# Customize chart
plt.title('Top 5 Customers by Estimated Salary')
plt.xlabel('Estimated Salary')
plt.ylabel('Customer')
plt.legend(title='Geography', loc='lower right')
plt.tight_layout()
plt.show()

# %%
selected_columns = merged_df[['Surname','Balance','Geography','Tenure Category','Tenure','CreditScore','IsActiveMember']]
top_25_Tenure = selected_columns.sort_values(by='Tenure', ascending=False).groupby('Tenure Category').head(10)

# %%
top_25_Tenure
# Out:
#           Surname    Balance Geography Tenure Category  Tenure  CreditScore  \
# 1278     Clements       0.00    France     long-termed      10          654
# 4251     McIntyre  102185.42   Germany     long-termed      10          717
# 2383         Gray  128039.01     Spain     long-termed      10          682
# 8358         West  118588.83   Germany     long-termed      10          692
# 4305          Hou       0.00    France     long-termed      10          626
# 4290         Chen  112536.57    France     long-termed      10          666
# 4284          Yin  145988.65    France     long-termed      10          787
# 2404       George  103121.33     Spain     long-termed      10          714
# 7087     Hamilton  144684.03    France     long-termed      10          694
# 2439          Hsu       0.00     Spain     long-termed      10          508
# 2035      Ershova       0.00    France      mid-termed       6          722
# 2435      Blesing  125552.96   Germany      mid-termed       6          695
# 2087        White  150200.23     Spain      mid-termed       6          663
# 6717         Pham  109663.47     Spain      mid-termed       6          707
# 2406      Russell   98862.54    France      mid-termed       6          703
# 6753         Kang       0.00     Spain      mid-termed       6          577
# 2428      Butcher   86167.82    France      mid-termed       6          701
# 4830        Brown   81070.34    France      mid-termed       6          817
# 6808      Horsley  106596.29    France      mid-termed       6          753
# 8345      Moretti       0.00    France      mid-termed       6          630
# 2571       Forbes  163139.27    France    Short-termed       2          696
# 4844       Piccio  158584.28   Germany    Short-termed       2          553
# 1682         Dean  125845.66   Germany    Short-termed       2          585
# 9369       Martin       0.00    France    Short-termed       2          793
# 8240       Buccho  103769.22   Germany    Short-termed       2          776
# 2579  Castiglione   56116.30   Germany    Short-termed       2          619
# 9097   Fiorentino   69974.66     Spain    Short-termed       2          494
# 2584      Du Cane  154485.74    France    Short-termed       2          724
# 1493      Galkina   45472.28    France    Short-termed       2          564
# 2638         Hill  171770.55   Germany    Short-termed       2          657
#
#      IsActiveMember
# 1278             No
# 4251             No
# 2383            Yes
# 8358            Yes
# 4305             No
# 4290            Yes
# 4284            Yes
# 2404            Yes
# 7087            Yes
# 2439            Yes
# 2035            Yes
# 2435             No
# 2087            Yes
# 6717            Yes
# 2406             No
# 6753            Yes
# 2428             No
# 4830             No
# 6808             No
# 8345            Yes
# 2571            Yes
# 4844             No
# 1682             No
# 9369             No
# 8240             No
# 2579             No
# 9097             No
# 2584             No
# 1493            Yes
# 2638             No

# %%
selected_columns = merged_df[['Surname','Balance','Geography','Tenure Category','Tenure','CreditScore','IsActiveMember']]
top_25_Balance = selected_columns.sort_values(by='Balance', ascending=False).groupby('Tenure Category').head(10)

# %%
top_25_Balance
# Out:
#          Surname    Balance Geography Tenure Category  Tenure  CreditScore  \
# 7650          Lo  250898.09     Spain      mid-termed       3          655
# 5996      To Rot  238387.56    France      mid-termed       3          583
# 5942      Haddon  222267.63     Spain     long-termed       9          749
# 239     McIntosh  221532.80     Spain      mid-termed       3          489
# 805         Shaw  216109.88     Spain      mid-termed       5          663
# 1319       Dilke  214346.96   Germany      mid-termed       4          650
# 1131        Chia  213146.20     Spain    Short-termed       2          584
# 8155       Moore  212778.20    France      mid-termed       3          850
# 2138     Thomson  212696.32   Germany      mid-termed       3          634
# 8594         Mao  212692.97    France      mid-termed       4          592
# 4991     Udinesi  212314.03    France     long-termed       9          541
# 4218   Macartney  211774.31    France    Short-termed       1          850
# 6841   Macdonald  210433.08    France      mid-termed       4          596
# 6236     Fleming  209767.31     Spain    Short-termed       2          672
# 490         Webb  209490.21     Spain    Short-termed       1          706
# 5768       Burke  208165.53    France    Short-termed       2          479
# 8141    Atkinson  207034.96     Spain      mid-termed       4          684
# 9195  Olisaemeka  206868.78   Germany     long-termed       9          573
# 2474      Coates  206663.75    France     long-termed       8          504
# 8756          Ku  206329.65    France     long-termed       7          564
# 3928   Golovanov  205962.00    France     long-termed       7          508
# 7179       Conti  205770.78   Germany    Short-termed       2          716
# 7223       Ts'ui  204223.03     Spain     long-termed       8          463
# 4946        Kang  201696.07    France     long-termed       8          625
# 9119      Bancks  201009.64    France     long-termed       9          669
# 8442  Napolitani  200724.96    France     long-termed      10          682
# 4115    Chidubem  200322.45     Spain    Short-termed       2          592
# 9662       McKay  200117.76   Germany    Short-termed       1          699
# 8026        Tang  198113.86    France    Short-termed       1          498
# 2327        Tsao  197041.80    France    Short-termed       0          594
#
#      IsActiveMember
# 7650            Yes
# 5996            Yes
# 5942             No
# 239              No
# 805             Yes
# 1319             No
# 1131             No
# 8155            Yes
# 2138             No
# 8594             No
# 4991            Yes
# 4218             No
# 6841            Yes
# 6236            Yes
# 490             Yes
# 5768             No
# 8141             No
# 9195            Yes
# 2474             No
# 8756            Yes
# 3928             No
# 7179             No
# 7223             No
# 4946             No
# 9119             No
# 8442            Yes
# 4115            Yes
# 9662             No
# 8026             No
# 2327             No

# %%
top_balances = merged_df[['Surname', 'Balance', 'Geography']].sort_values(by='Balance', ascending=False).head(10)
# Plot
plt.figure(figsize=(12, 6))
ax = sb.barplot(data=top_balances, x='Surname', y='Balance', hue='Geography', palette='Set2')
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', padding=3)

# Customize plot
plt.title('Top 10 Customer By Account Balance')
plt.xlabel('Surname')
plt.ylabel('Balance')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Geography')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 50% of the top 10 Balance holders are from spain

# %% [markdown]
# #### Ratio of Active Members

# %%
# Count values in 'IsActiveMember' column (column 5)
active_counts = merged_df['IsActiveMember'].value_counts()

# Plot pie chart
plt.figure(figsize=(4, 4))
plt.pie(active_counts, labels=active_counts.index, autopct='%1.1f%%', startangle=100, colors=['#66b3ff', '#ff9999'])

# Customize
plt.title('Active vs Inactive Members')
plt.axis('equal')  # Makes it a perfect circle
plt.tight_layout()
plt.show()

# %% [markdown]
# #### What are the numbers for Active and inactive members

# %%
# Group data
grouped = merged_df.groupby(['Geography', 'IsActiveMember'])['CustomerId'].count().unstack().fillna(0)

# Define colors
colors = {'Yes': '#4CAF50', 'No': '#F44336'}  # Green for Yes, Red for No

# Plot
ax = grouped.plot(kind='bar', stacked=True, color=[colors.get(x, '#333') for x in grouped.columns], figsize=(8,6), edgecolor='black')

# Add labels inside bars
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        if height > 0:
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + height / 2,
                int(height),
                ha='center',
                va='center',
                color='white',
                fontsize=10,
                fontweight='bold'
            )

# Labels and title
plt.title('Active vs Inactive Customers by Geography')
plt.xlabel('Geography')
plt.ylabel('Number of Customers')
plt.legend(title='Is Active Member')
plt.tight_layout()
plt.show()

# %%
# Group by Geography and Exited status
grouped_exit = merged_df.groupby(['Geography', 'Exited'])['CustomerId'].count().unstack().fillna(0)

# Define clear labels
exit_labels = {0: 'Left', 1: 'Active'}
grouped_exit.columns = [exit_labels.get(col, col) for col in grouped_exit.columns]

# Colors: Red for left, Blue for active
colors = {'Left': '#FF6F61', 'Active': '#6EC6FF'}

# Plot
ax = grouped_exit.plot(
    kind='bar',
    stacked=True,
    color=[colors[col] for col in grouped_exit.columns],
    figsize=(8, 6),
    edgecolor='black'
)

# Add value labels inside the bars
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        if height > 0:
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + height / 2,
                int(height),
                ha='center',
                va='center',
                color='white',
                fontsize=10,
                fontweight='bold'
            )

# Customize chart
plt.title('Customer Retention by Geography')
plt.xlabel('Geography')
plt.ylabel('Number of Customers')
plt.legend(title='Customer Status')
plt.tight_layout()
plt.show()
